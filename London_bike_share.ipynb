# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/Users/samarpanbothra/Desktop/london_merged _data.csv")

# %%
df.info()
df['weather_code'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  object
#  1   Date          17414 non-null  object
#  2   Time          17414 non-null  object
#  3   cnt           17414 non-null  int64
#  4   t1            17414 non-null  float64
#  5   t2            17414 non-null  float64
#  6   hum           17414 non-null  float64
#  7   wind_speed    17414 non-null  float64
#  8   weather_code  17414 non-null  int64
#  9   is_holiday    17414 non-null  int64
#  10  is_weekend    17414 non-null  int64
#  11  season        17414 non-null  int64
# dtypes: float64(4), int64(5), object(3)
# memory usage: 1.6+ MB
# weather_code
# 1     6150
# 2     4034
# 3     3551
# 7     2141
# 4     1464
# 26      60
# 10      14
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#        timestamp   Date   Time    cnt     t1     t2    hum  wind_speed  \
# 0          False  False  False  False  False  False  False       False
# 1          False  False  False  False  False  False  False       False
# 2          False  False  False  False  False  False  False       False
# 3          False  False  False  False  False  False  False       False
# 4          False  False  False  False  False  False  False       False
# ...          ...    ...    ...    ...    ...    ...    ...         ...
# 17409      False  False  False  False  False  False  False       False
# 17410      False  False  False  False  False  False  False       False
# 17411      False  False  False  False  False  False  False       False
# 17412      False  False  False  False  False  False  False       False
# 17413      False  False  False  False  False  False  False       False
#
#        weather_code  is_holiday  is_weekend  season
# 0             False       False       False   False
# ...

# %%
df.columns
# Out:
# Index(['timestamp', 'Date', 'Time', 'cnt', 't1', 't2', 'hum', 'wind_speed',
#        'weather_code', 'is_holiday', 'is_weekend', 'season'],
#       dtype='object')

# %%
data = df.drop('timestamp', axis=1)
data
# Out:
#          Date   Time   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      1/4/15   0:00   182  3.0  2.0   93.0         6.0             3
# 1      1/4/15   1:00   138  3.0  2.5   93.0         5.0             1
# 2      1/4/15   2:00   134  2.5  2.5   96.5         0.0             1
# 3      1/4/15   3:00    72  2.0  2.0  100.0         0.0             1
# 4      1/4/15   4:00    47  2.0  0.0   93.0         6.5             1
# ...       ...    ...   ...  ...  ...    ...         ...           ...
# 17409  1/3/17  19:00  1042  5.0  1.0   81.0        19.0             3
# 17410  1/3/17  20:00   541  5.0  1.0   81.0        21.0             4
# 17411  1/3/17  21:00   337  5.5  1.5   78.5        24.0             4
# 17412  1/3/17  22:00   224  5.5  1.5   76.0        23.0             4
# 17413  1/3/17  23:00   139  5.0  1.0   76.0        22.0             2
#
#        is_holiday  is_weekend  season
# 0               0           1       3
# 1               0           1       3
# ...

# %%
#clean up road owner group
import pandas as pd

# Assuming you have a DataFrame called data_explore

# Define the mapping of levels to their replacements
weather_code_description = {
    1: 'Clear',
    2: 'Few clouds',
    3: 'Broken clouds',
    4: 'Cloudy',
    7: 'Light rain',
    10: 'Rain with thunderstorm',
    26: 'Snowfall',
    94: 'Freezing Fog'
}

# Replace the levels in the 'road_owner' column
data['weather_code'] = data['weather_code'].replace(weather_code_description)


# Print the DataFrame with the updated 'road_owner' column
data['weather_code'].value_counts()
# Out:
# weather_code
# Clear                     6150
# Few clouds                4034
# Broken clouds             3551
# Light rain                2141
# Cloudy                    1464
# Snowfall                    60
# Rain with thunderstorm      14
# Name: count, dtype: int64

# %%
# 1. Impact of Weather on Bike Sharing
plt.figure(figsize=(10, 6))
sns.barplot(x="weather_code", y="cnt", data=df)
plt.title("Impact of Weather on Bike Sharing")
plt.xlabel("Weather ")
plt.ylabel("Bike Share Count")
plt.savefig('weather_bar_plot.png')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          17414 non-null  object
#  1   Time          17414 non-null  object
#  2   cnt           17414 non-null  int64
#  3   t1            17414 non-null  float64
#  4   t2            17414 non-null  float64
#  5   hum           17414 non-null  float64
#  6   wind_speed    17414 non-null  float64
#  7   weather_code  17414 non-null  int64
#  8   is_holiday    17414 non-null  int64
#  9   is_weekend    17414 non-null  int64
#  10  season        17414 non-null  int64
# dtypes: float64(4), int64(5), object(2)
# memory usage: 1.5+ MB

# %%
data.corr(numeric_only = [True])
# Out:
#                    cnt        t1        t2       hum  wind_speed  \
# cnt           1.000000  0.388798  0.369035 -0.462901    0.116295
# t1            0.388798  1.000000  0.988344 -0.447781    0.145471
# t2            0.369035  0.988344  1.000000 -0.403495    0.088409
# hum          -0.462901 -0.447781 -0.403495  1.000000   -0.287789
# wind_speed    0.116295  0.145471  0.088409 -0.287789    1.000000
# weather_code -0.166633 -0.097114 -0.098385  0.334750    0.124803
# is_holiday   -0.051698 -0.042233 -0.040051  0.032068   -0.002606
# is_weekend   -0.096499 -0.005342 -0.008510  0.028098    0.011479
# season       -0.116180 -0.285851 -0.285900  0.290381    0.010305
#
#               weather_code  is_holiday  is_weekend    season
# cnt              -0.166633   -0.051698   -0.096499 -0.116180
# t1               -0.097114   -0.042233   -0.005342 -0.285851
# t2               -0.098385   -0.040051   -0.008510 -0.285900
# hum               0.334750    0.032068    0.028098  0.290381
# ...

# %%
# Group the data by season and calculate the mean bike sharing counts for each season
seasonal_data = data.groupby('season')['cnt'].mean()

# Define standard colors for each season
colors = ['blue', 'green', 'orange', 'purple']

# Plotting the results
plt.figure(figsize=(10, 6))
seasonal_data.plot(kind='bar', color=colors, alpha=0.7)

# Adding labels and title
plt.xlabel('Season')
plt.ylabel('Average Bike Sharing Counts')
plt.title('Average Bike Sharing Usage Across Seasons')

# Display the plot
plt.show()

# %%
# 1. Impact of Weather on Bike Sharing
plt.figure(figsize=(10, 6))
sns.barplot(x="weather_code", y="cnt", data=df)
plt.title("Impact of Weather on Bike Sharing")
plt.xlabel("Weather Code")
plt.ylabel("Bike Share Count")
plt.savefig('weather_bar_plot.png')
plt.show()

# %%
# 2. Seasonal Trends in Bike Sharing
plt.figure(figsize=(10, 6))
sns.boxplot(x="season", y="cnt", data=df)
plt.title("Seasonal Trends in Bike Sharing")
plt.xlabel("Season")
plt.ylabel("Bike Share Count")
plt.savefig('Seasonal trends.png')

plt.show()

# %%
# 3. Temperature and Bike Sharing
plt.figure(figsize=(10, 6))
sns.scatterplot(x="t1", y="cnt", data=df)
plt.title("Temperature and Bike Sharing")
plt.xlabel("Real Temperature (C)")
plt.ylabel("Bike Share Count")
plt.savefig('Temperature.png')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x="is_holiday", y="cnt", hue="is_weekend", data=df)
plt.title("Impact of Holidays and Weekends on Bike Sharing")
plt.xlabel("Is Holiday")
plt.ylabel("Bike Share Count")
plt.savefig('Holiday.png')

plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x="hum", y="cnt", data=df)
plt.title("Humidity and Bike Sharing")
plt.xlabel("Humidity (%)")
plt.ylabel("Bike Share Count")
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['weather_code'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("Weather Code Distribution")
plt.show()

# %%
# 8. Impact of Weather on Weekends
plt.figure(figsize=(12, 8))
sns.lineplot(x="weather_code", y="cnt", hue="is_weekend", data=df)
plt.title("Impact of Weather on Bike Sharing on Weekends vs. Weekdays")
plt.xlabel("Weather Code")
plt.ylabel("Bike Share Count")
plt.savefig('weekend.png')
plt.show()

# %%
# 9. Temperature "Feels Like" vs. Actual Temperature
plt.figure(figsize=(10, 6))
sns.scatterplot(x="t1", y="t2", data=df)
plt.title("Temperature 'Feels Like' vs. Actual Temperature")
plt.xlabel("Real Temperature (C)")
plt.ylabel("Feels Like Temperature (C)")
plt.show()

# %%
# 10. Long-Term Trends
plt.figure(figsize=(12, 6))
df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp')['cnt'].plot()
plt.title("Long-Term Trends in Bike Sharing")
plt.xlabel("Timestamp")
plt.ylabel("Bike Share Count")
plt.show()
# Out:
# /var/folders/g7/v_lkt1k574372svst86n5y7r0000gn/T/ipykernel_59392/237498612.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['timestamp'] = pd.to_datetime(df['timestamp'])
